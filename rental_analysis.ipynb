# %% [markdown]
# # San Francisco Housing Cost Analysis
#
# In this assignment, you will perform fundamental analysis for the San Francisco housing market to allow potential real estate investors to choose rental investment properties.

# %%
# imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Mapbox API key
load_dotenv()
map_box_api = os.getenv("mapbox")

# %%
#print(map_box_api)

# %% [markdown]
# ## Load Data

# %%
# Read the census data into a Pandas DataFrame
file_path = Path("Data/sfo_neighborhoods_census_data.csv")
sfo_data = pd.read_csv(file_path, index_col="year") #reads in the csv file and makes index column = year
sfo_data.head()
# Out:
#           neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010      Alamo Square           291.182945         372560        1239
# 2010        Anza Vista           267.932583         372560        1239
# 2010           Bayview           170.098665         372560        1239
# 2010  Buena Vista Park           347.394919         372560        1239
# 2010  Central Richmond           319.027623         372560        1239

# %% [markdown]
# - - -

# %% [markdown]
# ## Housing Units Per Year
#
# In this section, you will calculate the number of housing units per year and visualize the results as a bar chart using the Pandas plot function.
#
# **Hint:** Use the Pandas `groupby` function.
#
# **Optional challenge:** Use the min, max, and std to scale the y limits of the chart.

# %%
# Calculate the mean number of housing units per year (hint: use groupby) 
housing_units = (sfo_data['housing_units'] #selects only these 2 columns
                        .groupby(['year']) 
                        #groupby by allows us to use functions on specific data, like count and sum
                        #grouping by year for housing units
                        .mean()
                        )
housing_units = housing_units.astype(int)  #makes these values displayed as intergers

housing_units
# Out:
# year
# 2010    372560
# 2011    374507
# 2012    376454
# 2013    378401
# 2014    380348
# 2015    382295
# 2016    384242
# Name: housing_units, dtype: int64

# %%
# Save the dataframe as a csv file
housing_units.to_csv('housing_units.csv') #this exports a csv_file with housing_units dataframe

# %%
# Use the Pandas plot function to plot the average housing units per year.
# Note: You will need to manually adjust the y limit of the chart using the min and max values from above.
housing_units.plot(kind = 'bar', ylabel = 'Housing Units', xlabel = 'Year', 
                   title = 'Housing Units in San Francisco from 2010 to 2016')
# Out:
# <AxesSubplot:title={'center':'Housing Units in San Francisco from 2010 to 2016'}, xlabel='Year', ylabel='Housing Units'>

# %%
# Optional Challenge: Use the min, max, and std to scale the y limits of the chart
housing_units_bar = housing_units.plot(kind = 'bar', ylabel = 'Housing Units', xlabel = 'Year',
                   ylim = (housing_units.min()-housing_units.std(), housing_units.max()+housing_units.std()),
                   title = 'Housing Units in San Francisco from 2010 to 2016')
#ylim sets the interval for the y-axis, specfically it's minimum housing units minus one standard deviation and
#and it goes to the maximum housing units plus one standard deviation (provides extra space for the bars)

# %% [markdown]
# - - -

# %% [markdown]
# ## Average Housing Costs in San Francisco Per Year
#
# In this section, you will calculate the average monthly rent and the average price per square foot for each year. An investor may wish to better understand the sales price of the rental property over time. For example, a customer will want to know if they should expect an increase or decrease in the property value over time so they can determine how long to hold the rental property.  Plot the results as two line charts.
#
# **Optional challenge:** Plot each line chart in a different color.

# %%
# Calculate the average sale price per square foot and average gross rent
housing_costs = (sfo_data[['sale_price_sqr_foot', 'gross_rent']]#selects only these 2 columns
                        .groupby(['year']) 
                        #groupby by allows us to use functions on specific data, like mean
                        #grouping by year
                        .mean()
                        )

housing_costs = housing_costs.astype({'gross_rent' : int}) #this makes the gross_rent column consist of integers
housing_costs
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353        1239
# 2011           341.903429        1530
# 2012           399.389968        2324
# 2013           483.600304        2971
# 2014           556.277273        3528
# 2015           632.540352        3739
# 2016           697.643709        4390

# %%
# Create two line charts, one to plot the average sale price per square foot and another for average montly rent

# Line chart for average sale price per square foot
sqft_plot = housing_costs.plot.line(y='sale_price_sqr_foot', color = 'purple')
sqft_plot.set_xlabel('Year', fontsize = 14) #lets the label for x-axis and font size
sqft_plot.set_ylabel('Price per SqFt', fontsize = 12)#lets the label for y-axis and font size
sqft_plot.set_title('Average Sales Price per SqFt by Year', fontsize = 14, fontweight='bold')#sets the title and fontsize, and makes it bold.
sqft_plot.set_xlim(2010,2016) #this sets the interval for the x-axis



# Line chart for average montly rent
rent_plot = housing_costs.plot.line(y = 'gross_rent', color = 'red') #.plot.line is a dfferent way of plotting
#color parameter changes the color of the line, and (y =) parameter sets specific column to Y axis
rent_plot.set_xlabel('Year', fontsize = 14) #lets the label for x-axis and font size
rent_plot.set_ylabel('Gross Rent', fontsize = 12)#lets the label for y-axis and font size
rent_plot.set_title('Average Gross Rent by Year', fontsize = 14, fontweight='bold')#sets the title and fontsize, and makes it bold.
rent_plot.set_xlim(2010,2016) #this sets the interval for the x-axis
# Out:
# (2010.0, 2016.0)

# %%
#Alternative way you can create these plots, with less customization for the fonts
sqft2_plot = housing_costs.plot(kind = 'line', y = 'sale_price_sqr_foot',
                              title = 'Average Sales Price per SqFt by Year',
                              xlabel = 'Year', ylabel = 'Price per SqFt',
                              xlim = (2010,2016), color = 'purple')

# %% [markdown]
# - - -

# %% [markdown]
# ## Average Prices by Neighborhood
#
# In this section, you will use hvplot to create two interactive visulizations of average prices with a dropdown selector for the neighborhood. The first visualization will be a line plot showing the trend of average price per square foot over time for each neighborhood.  The second will be a line plot showing the trend of average montly rent over time for each neighborhood.
#
# **Hint:** It will be easier to create a new DataFrame from grouping the data and calculating the mean prices for each year and neighborhood

# %%
sfo_data.head(10)
# Out:
#           neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010      Alamo Square           291.182945         372560        1239
# 2010        Anza Vista           267.932583         372560        1239
# 2010           Bayview           170.098665         372560        1239
# 2010  Buena Vista Park           347.394919         372560        1239
# 2010  Central Richmond           319.027623         372560        1239
# 2010    Central Sunset           418.172493         372560        1239
# 2010    Corona Heights           369.359338         372560        1239
# 2010        Cow Hollow           569.379968         372560        1239
# 2010     Croker Amazon           165.645730         372560        1239
# 2010   Diamond Heights           456.930822         372560        1239

# %%
# Group by year and neighborhood and then create a new dataframe of the mean values
new_df = sfo_data.groupby(['year','neighborhood']).mean().reset_index()
new_df.head()
#reset index so 'year' is a column
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945       372560.0      1239.0
# 1  2010        Anza Vista           267.932583       372560.0      1239.0
# 2  2010           Bayview           170.098665       372560.0      1239.0
# 3  2010  Buena Vista Park           347.394919       372560.0      1239.0
# 4  2010  Central Richmond           319.027623       372560.0      1239.0

# %%
# Use hvplot to create an interactive line chart of the average price per sq ft.
# The plot should have a dropdown selector for the neighborhood
avgprice_hvplot = new_df.hvplot(x = 'year', y = 'sale_price_sqr_foot', groupby = 'neighborhood',
                               ylabel = 'Avg. Sale Price per Square Foot', xlabel = 'Year')
avgprice_hvplot
#.hvplot creats line plot by default
#used the groupby parameter to create the drop down menu of different neighborhoods
#x = and y = parameter determines the axis'
# Out:
# :DynamicMap   [neighborhood]
#    :Curve   [year]   (sale_price_sqr_foot)

# %%
# Use hvplot to create an interactive line chart of the average monthly rent.
# The plot should have a dropdown selector for the neighborhood
avg_monthly_rent_hvplot = new_df.hvplot(x = 'year', y = 'gross_rent', ylabel = 'Avg. Gross Rent Price per Year',
                                      xlabel = 'Year', groupby = 'neighborhood')
avg_monthly_rent_hvplot
#used the groupby parameter to create the drop down menu of different neighborhoods
#x = and y = parameter determines the axis'
# Out:
# :DynamicMap   [neighborhood]
#    :Curve   [year]   (gross_rent)

# %% [markdown]
# ## The Top 10 Most Expensive Neighborhoods
#
# In this section, you will need to calculate the mean sale price per square foot for each neighborhood and then sort the values to obtain the top 10 most expensive neighborhoods on average. Plot the results as a bar chart.

# %%
# Getting the data from the top 10 expensive neighborhoods to own

expensive_df = sfo_data.groupby(['neighborhood']).mean().reset_index()
#this data frame is grouped by neighborhood and finds the average values for each column

expensive_df = expensive_df.sort_values('sale_price_sqr_foot', ascending = False).reset_index()
#sorts values based on the column 'sale_price_sqr_foot', and sorts them from greatest to least
#.reset_index resets the index once again so that it starts from 0

expensive_df = expensive_df.iloc[0:10] #this locates the top 10 rows
expensive_df.drop(columns=['index'], inplace=True) #this drops the extra index column
expensive_df #we now have the top 10 most expensive neighborhoods
# Out:
#             neighborhood  sale_price_sqr_foot  housing_units   gross_rent
# 0  Union Square District           903.993258      377427.50  2555.166667
# 1         Merced Heights           788.844818      380348.00  3414.000000
# 2          Miraloma Park           779.810842      375967.25  2155.250000
# 3        Pacific Heights           689.555817      378401.00  2817.285714
# 4          Westwood Park           687.087575      382295.00  3959.000000
# 5         Telegraph Hill           676.506578      378401.00  2817.285714
# 6       Presidio Heights           675.350212      378401.00  2817.285714
# 7             Cow Hollow           665.964042      378401.00  2817.285714
# 8           Potrero Hill           662.013613      378401.00  2817.285714
# 9            South Beach           650.124479      375805.00  2099.000000

# %%
# Plotting the data from the top 10 expensive neighborhoods
top_ten_expensive_plot = expensive_df.hvplot.bar(x = 'neighborhood',
                                           y = 'sale_price_sqr_foot', title = 'Top 10 Expensive Neighborhoods in SFO',
                                           rot = 90, height = 500, xlabel = 'Neighborhood',
                                                 ylabel = 'Avg. Sale Price per Sqaure Foot')
top_ten_expensive_plot
#hvplot.bar creats a bar chart
#height adjusts the high of the bar plot
#rot makes each entry in x-axis rotate 90 degrees so it can be read easier
# Out:
# :Bars   [neighborhood]   (sale_price_sqr_foot)

# %% [markdown]
# ## Comparing cost to purchase versus rental income
#
# In this section, you will use `hvplot` to create an interactive visualization with a dropdown selector for the neighborhood. This visualization will feature a side-by-side comparison of average price per square foot versus average montly rent by year.
#
# **Hint:** Use the `hvplot` parameter, `groupby`, to create a dropdown selector for the neighborhood.

# %%
# Fetch the previously generated DataFrame that was grouped by year and neighborhood (new_df)
new_df.head(10)
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945       372560.0      1239.0
# 1  2010        Anza Vista           267.932583       372560.0      1239.0
# 2  2010           Bayview           170.098665       372560.0      1239.0
# 3  2010  Buena Vista Park           347.394919       372560.0      1239.0
# 4  2010  Central Richmond           319.027623       372560.0      1239.0
# 5  2010    Central Sunset           418.172493       372560.0      1239.0
# 6  2010    Corona Heights           369.359338       372560.0      1239.0
# 7  2010        Cow Hollow           569.379968       372560.0      1239.0
# 8  2010     Croker Amazon           165.645730       372560.0      1239.0
# 9  2010   Diamond Heights           456.930822       372560.0      1239.0

# %%
# Plotting the data 
columns = ['sale_price_sqr_foot', 'gross_rent']
comparison_barplot = new_df.hvplot.bar(groupby = 'neighborhood', y = columns, ylabel = 'Price',
                                      rot = 90, x = 'year', height = 500)

comparison_barplot
#hvplot.bar createas a bar chart
#to have multiplie bars, I made (y =) a list. This list contains the 2 different variables for the bar chart
#groupby lets us have a drop down tab for each neighborhood
#rot = 90 makes it so the x-axis varibales are easier to read.
# Out:
# :DynamicMap   [neighborhood]
#    :Bars   [year,Variable]   (value)

# %% [markdown]
# - - -

# %% [markdown]
# ## Neighborhood Map
#
# In this section, you will read in neighborhoods location data and build an interactive map with the average house value per neighborhood. Use a `scatter_mapbox` from Plotly express to create the visualization. Remember, you will need your Mapbox API key for this.

# %% [markdown]
# ### Load Location Data

# %%
# Load neighborhoods coordinates data
file_path2 = Path("Data/neighborhoods_coordinates.csv")
location_data = pd.read_csv(file_path2)
location_data.head()
# Out:
#       Neighborhood        Lat         Lon
# 0     Alamo Square  37.791012 -122.402100
# 1       Anza Vista  37.779598 -122.443451
# 2          Bayview  37.734670 -122.401060
# 3  Bayview Heights  37.728740 -122.410980
# 4   Bernal Heights  37.728630 -122.443050

# %% [markdown]
# ### Data Preparation
#
# You will need to join the location data with the mean values per neighborhood.
#
# 1. Calculate the mean values for each neighborhood.
#
# 2. Join the average values with the neighborhood locations.

# %%
# Calculate the mean values for each neighborhood
neighborhood_mean_df = sfo_data.groupby(['neighborhood']).mean().reset_index()
neighborhood_mean_df.head()
# Out:
#       neighborhood  sale_price_sqr_foot  housing_units   gross_rent
# 0     Alamo Square           366.020712       378401.0  2817.285714
# 1       Anza Vista           373.382198       379050.0  3031.833333
# 2          Bayview           204.588623       376454.0  2318.400000
# 3  Bayview Heights           590.792839       382295.0  3739.000000
# 4  Bernal Heights            576.746488       379374.5  3080.333333

# %%
# Join the average values with the neighborhood locations
neighborhood_concat = pd.concat([location_data, neighborhood_mean_df], axis=1).dropna()
#pd.concat lets us combine the 2 dataframes, axis = 1 means join by columns.

neighborhood_concat.drop(columns=['neighborhood'], inplace=True) #drops extra neighborhood column

neighborhood_concat.head(6)
# Out:
#        Neighborhood        Lat         Lon  sale_price_sqr_foot  \
# 0      Alamo Square  37.791012 -122.402100           366.020712
# 1        Anza Vista  37.779598 -122.443451           373.382198
# 2           Bayview  37.734670 -122.401060           204.588623
# 3   Bayview Heights  37.728740 -122.410980           590.792839
# 4    Bernal Heights  37.728630 -122.443050           576.746488
# 5  Buena Vista Park  37.768160 -122.439330           452.680591
#
#    housing_units   gross_rent
# 0       378401.0  2817.285714
# 1       379050.0  3031.833333
# 2       376454.0  2318.400000
# 3       382295.0  3739.000000
# 4       379374.5  3080.333333
# 5       378076.5  2698.833333

# %% [markdown]
# ### Mapbox Visualization
#
# Plot the average values per neighborhood using a Plotly express `scatter_mapbox` visualization.

# %%
# Set the mapbox access token
#print(map_box_api) to check 
px.set_mapbox_access_token(map_box_api) 

# Create a scatter mapbox to analyze neighborhood info
mapbox_plot = px.scatter_mapbox(
    neighborhood_concat,
    lat="Lat",
    lon="Lon",
    color="gross_rent", 
    size="sale_price_sqr_foot",
    height = 500,
    zoom = 11,
    title = 'Average Sale Price per Square Foot and Gross Rent in San Francisco'
)
mapbox_plot.show()

#px.scatter_mapbox creates the graph seen below
#color = makes each circle a different color based on gross_rent
#height adjusts the height of the scatter mapbox
#zoom adjusts how far the scatter mapbox is zoomed in
#size = makes each circle a different size based on 'sale_price_sqr_foot'

# %% [markdown]
# - - -

# %% [markdown]
# ## Cost Analysis - Optional Challenge
#
# In this section, you will use Plotly express to create visualizations that investors can use to interactively filter and explore various factors related to the house value of the San Francisco's neighborhoods.
#
# ### Create a DataFrame showing the most expensive neighborhoods in San Francisco by year

# %%
# Fetch the data from all expensive neighborhoods per year.
df_expensive_neighborhoods_per_year = new_df[new_df["neighborhood"].isin(expensive_df["neighborhood"])]
df_expensive_neighborhoods_per_year.head()
#this is the dataframe used for the sunbusrt graph
# Out:
#     year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 7   2010        Cow Hollow           569.379968       372560.0      1239.0
# 31  2010     Miraloma Park           680.608729       372560.0      1239.0
# 41  2010   Pacific Heights           496.516014       372560.0      1239.0
# 46  2010      Potrero Hill           491.450004       372560.0      1239.0
# 47  2010  Presidio Heights           549.417931       372560.0      1239.0

# %% [markdown]
# ### Create a parallel coordinates plot and parallel categories plot of most expensive neighborhoods in San Francisco per year

# %%
# Parallel Categories Plot
#I used expensive_df since that's what used in the homework instructions. 
#If I use the dataframe above this parallel categories plot wouldn't be legible.
parallel__categories_plot = px.parallel_categories(
    expensive_df, #dataframe we created from the top 10 expensive neighborhoods to own
    dimensions=["neighborhood", "sale_price_sqr_foot", "housing_units", "gross_rent"], #these are the columns for plotted data
    color="sale_price_sqr_foot", #different color depending on values in this column
    color_continuous_scale=px.colors.sequential.Inferno, #this was in demo, changes color of plot
    labels={
        "neighborhood": "Neighborhood",
        "sale_price_sqr_foot": "Sales price per Square Foot",
        "housing_units": "Housing Units",
        "gross_rent": "Gross Rent"
    },#relabels the dimiensions 
    title = 'Parallel Categories Analysis of Most Expensive San Francsico Neighborhoods',
    height = 500 #adjusts the height
)
parallel__categories_plot

#px.parallel_categories creates the plot below

# %%
# Parallel Coordinates Plot
parallel_coordinates_plot = px.parallel_coordinates(expensive_df, color = 'sale_price_sqr_foot', 
                        title = 'Parallel Coordinates Analysis of Most Expensive San Francsico Neighborhoods',
                       height = 500)
parallel_coordinates_plot
#used same dataframe that I used for the parallel categroies plot
#different color depending on values in 'sale_price_sqr_foot

# %% [markdown]
# ### Create a sunburst chart to conduct a costs analysis of most expensive neighborhoods in San Francisco per year

# %%
# Sunburst Plot
sunburst_plot = px.sunburst(df_expensive_neighborhoods_per_year, path=['year', 'neighborhood'],
                      values='sale_price_sqr_foot', color='gross_rent', height =700,
                      color_continuous_scale='Blues',
                     title = 'Cost Analysis of Most Expensive Neighborhoods in San Francsico per Year')
sunburst_plot
#I used this link to help create this
#https://plotly.com/python/sunburst-charts/
#I used the dataframe that shows the most expensive neighborhoods in San Francisco by year 
#color_continious_scale changes color of sunburst plot
#path contains a list on what is going to be plotted. Goes in order from center to outside
#so ['year', 'neighborhood'] means years are in the center, and neighborhoods are on the outside
#values are the values displayed when you hover over the plot
#color changes based on values on 'gross_rent'
